# %%
import boto3

def create_sagemaker_presigned_url(studio_domain, user_profile_name, expiration=300):
    client = boto3.client('sagemaker')
    response = client.create_presigned_domain_url(
        DomainId=studio_domain,
        UserProfileName=user_profile_name,
        ExpiresInSeconds=expiration
    )
    return response['AuthorizedUrl']

# Replace 'your-studio-domain-id' and 'your-user-profile-name' with your actual values
studio_domain_id = '<studio-domain>' 
user_profile_name = '<user-profile>'

# Create a pre-signed URL with a default expiration time of 1 hour
presigned_url = create_sagemaker_presigned_url(studio_domain_id, user_profile_name)

print("Pre-signed URL:", presigned_url)

# %%
# aws cli presigne url
# !aws sagemaker create-presigned-domain-url --region us-east-1 --domain-id <domain-id> --expires-in-seconds 300 --user-profile-name tech-summit-user1

# %%
import boto3
import numpy as np
import pandas as pd

# %% [markdown]
# ## Team Assignment

# %%
pdData = pd.read_csv("../../attendee/AWS 2차수 대상자 공유_Final.csv")
pdData = pdData.query('No.notna()')[["No", "팀명", "그룹명", "성명", "email"]]

# %%
group_info = [(8, "A"),(8, "B"), (7, "C"), (7, "D")]

# %%
start, end = 0, 0
pdGroup = pd.DataFrame("A", index=range(pdData.shape[0]), columns=["Group"])
for idx, (limit, group_name) in enumerate(group_info):
    end += limit
    pdGroup.iloc[start:end] = group_name
    start = end
pdData = pd.concat([pdData, pdGroup], axis=1)
pdData.to_csv(f'../../attendee/group/SEC-MX-Group-Assginment.csv', index=False)

for _, group_name in group_info:
    pdData.query("Group == @group_name").to_csv(f'../../attendee/group/SEC-MX-Group-{group_name}.csv', index=False)

# %%
pdData
# Out:
#       No                 팀명                     그룹명        성명  \
# 0    1.0                AI팀       AI Client개발그룹(MX)       곽현미
# 1    2.0    Application 개발팀    Application개발2그룹(MX)       권세환
# 2    3.0                AI팀       AI Client개발그룹(MX)       김설희
# 3    4.0                AI팀       AI Client개발그룹(MX)       이재철
# 4    5.0                AI팀       AI Client개발그룹(MX)       이준호
# 5    6.0    Application 개발팀    Application개발2그룹(MX)       김시정
# 6    7.0                AI팀   AI Solution 1Lab.(MX)       유지원
# 7    8.0                AI팀              AI개발그룹(MX)       윤재연
# 8    9.0                AI팀              AI개발그룹(MX)  바츠아난트나라얀
# 9   10.0                AI팀              AI개발그룹(MX)       김태구
# 10  11.0    Application 개발팀    Application개발1그룹(MX)       박지훈
# 11  12.0    Application 개발팀    Application개발1그룹(MX)       정기현
# 12  13.0    Application 개발팀    Application개발1그룹(MX)       김경은
# 13  14.0    Application 개발팀    Application개발1그룹(MX)       김병천
# 14  15.0    Application 개발팀    Application개발1그룹(MX)       한필규
# 15  16.0    Application 개발팀    Application개발1그룹(MX)       이근섭
# 16  17.0    Application 개발팀    Application개발1그룹(MX)       김진우
# 17  18.0    Application 개발팀    Application개발1그룹(MX)       유경민
# 18  19.0    Application 개발팀    Application개발1그룹(MX)       김영호
# 19  20.0    Application 개발팀    Application개발2그룹(MX)       정다은
# 20  21.0                AI팀              AI개발그룹(MX)       황윤준
# 21  22.0    Application 개발팀    Application개발2그룹(MX)       성기운
# 22  23.0    Application 개발팀    Application개발2그룹(MX)       노정환
# 23  24.0    Application 개발팀    Application개발2그룹(MX)       문주현
# 24  25.0       Framework개발팀  Basic Platform개발그룹(MX)       오규석
# 25  26.0       Framework개발팀         Graphic개발그룹(MX)       안형준
# 26  27.0       Framework개발팀         Graphic개발그룹(MX)       천우형
# 27  28.0       Framework개발팀         Graphic개발그룹(MX)       김종윤
# 28  29.0  Visual Solution 팀      Multimedia개발그룹(MX)       이수영
# 29  30.0  Visual Solution 팀      Multimedia개발그룹(MX)       박선미
#
#                         email Group
# 0     hyunmi.kwak@samsung.com     A
# 1     sehawn.kwon@samsung.com     A
# 2    sneeuwsh.kim@samsung.com     A
# 3       jc815.lee@samsung.com     A
# 4   junho4810.lee@samsung.com     A
# 5    standard.kim@samsung.com     A
# 6         jw1.yoo@samsung.com     A
# 7    jaeyeun.yoon@samsung.com     A
# 8      anant.vats@samsung.com     B
# 9     taegu83.kim@samsung.com     B
# 10     jh431.park@samsung.com     B
# 11   kihyun.chung@samsung.com     B
# 12        kke.kim@samsung.com     B
# 13     bk1204.kim@samsung.com     B
# 14    pilkyoo.han@samsung.com     B
# 15     ks1119.lee@samsung.com     B
# 16   jinwoo93.kim@samsung.com     C
# 17    kyungmin.yu@samsung.com     C
# 18     yh0409.kim@samsung.com     C
# 19     dani.jeong@samsung.com     C
# 20     yj.p.hwang@samsung.com     C
# 21   keewoon.sung@samsung.com     C
# 22       jh12.noh@samsung.com     C
# 23   joohyun.moon@samsung.com     D
# 24     kyuseok.oh@samsung.com     D
# 25   hyungjun.ahn@samsung.com     D
# 26       wh.cheon@samsung.com     D
# 27      jykim3353@samsung.com     D
# 28      sy.82.lee@samsung.com     D
# 29     sm136.park@samsung.com     D

# %% [markdown]
# ## Geterate CSV file for presigned url

# %%
def create_sagemaker_presigned_url(studio_domain, user_profile_name, expiration=300):
    client = boto3.client('sagemaker')
    response = client.create_presigned_domain_url(
        DomainId=studio_domain,
        UserProfileName=user_profile_name,
        ExpiresInSeconds=expiration
    )
    return response['AuthorizedUrl']

# %%
group = "C"
studio_domain = "d-qfwox2whpsa9"
pdData = pd.read_csv(f"../../attendee/group/SEC-MX-Group-{group}.csv")
pdData
# Out:
#      No               팀명                   그룹명   성명                     email  \
# 0  17.0  Application 개발팀  Application개발1그룹(MX)  김진우  jinwoo93.kim@samsung.com
# 1  18.0  Application 개발팀  Application개발1그룹(MX)  유경민   kyungmin.yu@samsung.com
# 2  19.0  Application 개발팀  Application개발1그룹(MX)  김영호    yh0409.kim@samsung.com
# 3  20.0  Application 개발팀  Application개발2그룹(MX)  정다은    dani.jeong@samsung.com
# 4  21.0              AI팀            AI개발그룹(MX)  황윤준    yj.p.hwang@samsung.com
# 5  22.0  Application 개발팀  Application개발2그룹(MX)  성기운  keewoon.sung@samsung.com
# 6  23.0  Application 개발팀  Application개발2그룹(MX)  노정환      jh12.noh@samsung.com
#
#   Group
# 0     C
# 1     C
# 2     C
# 3     C
# 4     C
# 5     C
# 6     C

# %%
instance = []
for idx in range(pdData.shape[0]):
    
    user_id = f'user_{str(idx+1).rjust(2, "0")}'
    user_profile = f'mx-{str(idx+1).rjust(2, "0")}'
    presigned_url = create_sagemaker_presigned_url(
        studio_domain=studio_domain,
        user_profile_name=user_profile
    )
    
    instance.append([user_id, user_profile, presigned_url])

pdURL = pd.DataFrame(instance, columns=["user_id", "user_profile", "실습_URL"])
pdData = pd.concat([pdData, pdURL], axis=1)
pdData.to_csv(f"../../attendee/실습-URL-정보-Group-{group}.csv", index=False)
pdData
# Out:
#      No               팀명                   그룹명   성명                     email  \
# 0  17.0  Application 개발팀  Application개발1그룹(MX)  김진우  jinwoo93.kim@samsung.com
# 1  18.0  Application 개발팀  Application개발1그룹(MX)  유경민   kyungmin.yu@samsung.com
# 2  19.0  Application 개발팀  Application개발1그룹(MX)  김영호    yh0409.kim@samsung.com
# 3  20.0  Application 개발팀  Application개발2그룹(MX)  정다은    dani.jeong@samsung.com
# 4  21.0              AI팀            AI개발그룹(MX)  황윤준    yj.p.hwang@samsung.com
# 5  22.0  Application 개발팀  Application개발2그룹(MX)  성기운  keewoon.sung@samsung.com
# 6  23.0  Application 개발팀  Application개발2그룹(MX)  노정환      jh12.noh@samsung.com
#
#   Group  user_id user_profile  \
# 0     C  user_01        mx-01
# 1     C  user_02        mx-02
# 2     C  user_03        mx-03
# 3     C  user_04        mx-04
# 4     C  user_05        mx-05
# 5     C  user_06        mx-06
# 6     C  user_07        mx-07
#
#                                               실습_URL
# 0  https://d-qfwox2whpsa9.studio.us-east-1.sagema...
# 1  https://d-qfwox2whpsa9.studio.us-east-1.sagema...
# 2  https://d-qfwox2whpsa9.studio.us-east-1.sagema...
# 3  https://d-qfwox2whpsa9.studio.us-east-1.sagema...
# 4  https://d-qfwox2whpsa9.studio.us-east-1.sagema...
# 5  https://d-qfwox2whpsa9.studio.us-east-1.sagema...
# 6  https://d-qfwox2whpsa9.studio.us-east-1.sagema...

# %% [markdown]
# ## 개인용 발급

# %%
import boto3

def create_sagemaker_presigned_url(studio_domain, user_profile_name, expiration=300):
    client = boto3.client('sagemaker')
    response = client.create_presigned_domain_url(
        DomainId=studio_domain,
        UserProfileName=user_profile_name,
        ExpiresInSeconds=expiration
    )
    return response['AuthorizedUrl']

# Replace 'your-studio-domain-id' and 'your-user-profile-name' with your actual values
studio_domain_id = studio_domain
user_profile_name = 'mx-10'

# Create a pre-signed URL with a default expiration time of 1 hour
presigned_url = create_sagemaker_presigned_url(studio_domain_id, user_profile_name)

print("Pre-signed URL:", presigned_url)
# Out:
# Pre-signed URL: https://d-qfwox2whpsa9.studio.us-east-1.sagemaker.aws/auth?token=eyJhbGciOiJIUzI1NiJ9.....VdkFP50I7GgHgAM1gSPS4GL9obysRJSY5kN2uZTuAyA
