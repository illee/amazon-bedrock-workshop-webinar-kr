# %%
import boto3

def create_sagemaker_presigned_url(studio_domain, user_profile_name, expiration=300):
    client = boto3.client('sagemaker')
    response = client.create_presigned_domain_url(
        DomainId=studio_domain,
        UserProfileName=user_profile_name,
        ExpiresInSeconds=expiration
    )
    return response['AuthorizedUrl']

# Replace 'your-studio-domain-id' and 'your-user-profile-name' with your actual values
studio_domain_id = '<studio-domain>' 
user_profile_name = '<user-profile>'

# Create a pre-signed URL with a default expiration time of 1 hour
presigned_url = create_sagemaker_presigned_url(studio_domain_id, user_profile_name)

print("Pre-signed URL:", presigned_url)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[5], line 17
#      14 user_profile_name = '<user-profile>'
#      16 # Create a pre-signed URL with a default expiration time of 1 hour
# ---> 17 presigned_url = create_sagemaker_presigned_url(studio_domain_id, user_profile_name)
#      19 print("Pre-signed URL:", presigned_url)
#
# Cell In[5], line 5, in create_sagemaker_presigned_url(studio_domain, user_profile_name, expiration)
#       3 def create_sagemaker_presigned_url(studio_domain, user_profile_name, expiration=300):
#       4     client = boto3.client('sagemaker')
# ----> 5     response = client.create_presigned_domain_url(
#       6         DomainId=studio_domain,
#       7         UserProfileName=user_profile_name,
#       8         ExpiresInSeconds=expiration
#       9     )
#      10     return response['AuthorizedUrl']
#
# File /opt/conda/lib/python3.10/site-packages/botocore/client.py:535, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     531     raise TypeError(
#     532         f"{py_operation_name}() only accepts keyword arguments."
#     533     )
#     534 # The "self" in this scope is referring to the BaseClient.
# --> 535 return self._make_api_call(operation_name, kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/botocore/client.py:980, in BaseClient._make_api_call(self, operation_name, api_params)
#     978     error_code = parsed_response.get("Error", {}).get("Code")
#     979     error_class = self.exceptions.from_code(error_code)
# --> 980     raise error_class(parsed_response, operation_name)
#     981 else:
#     982     return parsed_response
#
# ClientError: An error occurred (ValidationException) when calling the CreatePresignedDomainUrl operation: 2 validation errors detected: Value '<user-profile>' at 'userProfileName' failed to satisfy constraint: Member must satisfy regular expression pattern: ^[a-zA-Z0-9](-*[a-zA-Z0-9]){0,62}; Value '<studio-domain>' at 'domainId' failed to satisfy constraint: Member must satisfy regular expression pattern: ^d-(-*[a-z0-9]){1,61}

# %%
# aws cli presigne url
# !aws sagemaker create-presigned-domain-url --region us-east-1 --domain-id <domain-id> --expires-in-seconds 300 --user-profile-name tech-summit-user1
# Out:
# /bin/bash: line 1: domain-id: No such file or directory

# %% [markdown]
# ## Geterate CSV file for presigned url

# %%
import boto3
import pandas as pd

# %%
def create_sagemaker_presigned_url(studio_domain, user_profile_name, expiration=300):
    client = boto3.client('sagemaker')
    response = client.create_presigned_domain_url(
        DomainId=studio_domain,
        UserProfileName=user_profile_name,
        ExpiresInSeconds=expiration
    )
    return response['AuthorizedUrl']

# %%
pdData = pd.read_csv("../../mx-train-attendee/training-attendee-info.csv")

# %%
instance = []
for idx in range(pdData.shape[0]):
    
    user_id = f'user_{str(idx+1).rjust(2, "0")}'
    user_profile = f'mx-{str(idx+1).rjust(2, "0")}'
    presigned_url = create_sagemaker_presigned_url(
        studio_domain="d-b8m78vamvqp0",
        user_profile_name=user_profile
    )
    
    instance.append([user_id, user_profile, presigned_url])

pdURL = pd.DataFrame(instance, columns=["user_id", "user_profile", "실습_URL"])
pdData = pd.concat([pdData, pdURL], axis=1)
pdData.to_csv("../../mx-train-attendee/실습-URL-정보.csv", index=False)
pdData
# Out:
#     No                 팀명                     그룹명    성명  \
# 0    1                AI팀              AI개발그룹(MX)  김혜린
# 1    2                AI팀              AI개발그룹(MX)   이지용
# 2    3                AI팀              AI개발그룹(MX)   현대영
# 3    4                AI팀             AI개발그룹(MX)    최윤정
# 4    5                AI팀       AI Client개발그룹(MX)   김소현
# 5    6    Application 개발팀    Application개발2그룹(MX)   정명자
# 6    7    Application 개발팀    Application개발2그룹(MX)   백지예
# 7    8    Application 개발팀    Application개발2그룹(MX)   배종규
# 8    9    Application 개발팀    Application개발2그룹(MX)   김수진
# 9   10    Application 개발팀    Application개발1그룹(MX)   심형남
# 10  11    Application 개발팀    Application개발2그룹(MX)   홍수민
# 11  12    Application 개발팀    Application개발2그룹(MX)   장태익
# 12  13    Application 개발팀    Application개발2그룹(MX)   정병호
# 13  14    Application 개발팀    Application개발1그룹(MX)   이근섭
# 14  15    Application 개발팀    Application개발1그룹(MX)   안재진
# 15  16    Application 개발팀    Application개발1그룹(MX)    박성
# 16  17    Application 개발팀    Application개발1그룹(MX)   이범주
# 17  18    Application 개발팀    Application개발1그룹(MX)   이승엽
# 18  19    Application 개발팀    Application개발2그룹(MX)   진윤종
# 19  20    Application 개발팀    Application개발1그룹(MX)   이정헌
# 20  21       Framework개발팀         Graphic개발그룹(MX)   이효성
# 21  22       Framework개발팀   Core Platform개발그룹(MX)    강철
# 22  23       Framework개발팀  Basic Platform개발그룹(MX)   권현웅
# 23  24  Visual Solution 팀      Visual S/W개발그룹(MX)   이권주
# 24  25  Visual Solution 팀      Visual AI Lab.(MX)   손병준
# 25  26  Visual Solution 팀      Multimedia개발그룹(MX)   최명규
# 26  27  Visual Solution 팀      Visual AI Lab.(MX)   이민규
# 27  28  Visual Solution 팀      Visual AI Lab.(MX)   최명용
# 28  29  Visual Solution 팀      Multimedia개발그룹(MX)   김성환
#
#                           email  user_id user_profile  \
# 0      hyerin16.kim@samsung.com  user_01        mx-01
# 1       jiyongs.lee@samsung.com  user_02        mx-02
# 2         dy37.hyun@samsung.com  user_03        mx-03
# 3       yj0807.choi@samsung.com  user_04        mx-04
# 4      anna1014.kim@samsung.com  user_05        mx-05
# 5         mj.cheong@samsung.com  user_06        mx-06
# 6         jiye.baek@samsung.com  user_07        mx-07
# 7       jongkyu.bae@samsung.com  user_08        mx-08
# 8        sj0727.kim@samsung.com  user_09        mx-09
# 9           hn.shim@samsung.com  user_10        mx-10
# 10       sumin.hong@samsung.com  user_11        mx-11
# 11     taeik27.jang@samsung.com  user_12        mx-12
# 12      byhow.jeong@samsung.com  user_13        mx-13
# 13       ks1119.lee@samsung.com  user_14        mx-14
# 14        jj920.ahn@samsung.com  user_15        mx-15
# 15    sung1103.park@samsung.com  user_16        mx-16
# 16        bumju.lee@samsung.com  user_17        mx-17
# 17        sy616.lee@samsung.com  user_18        mx-18
# 18     yunjong2.jin@samsung.com  user_19        mx-19
# 19       jh0511.lee@samsung.com  user_20        mx-20
# 20     hyoseong.lee@samsung.com  user_21        mx-21
# 21      ksteel.kang@samsung.com  user_22        mx-22
# 22      hwoong.kwon@samsung.com  user_23        mx-23
# 23            kj.yi@samsung.com  user_24        mx-24
# 24         bj91.son@samsung.com  user_25        mx-25
# 25        core.choi@samsung.com  user_26        mx-26
# 26       mk8259.lee@samsung.com  user_27        mx-27
# 27  myeungyong.choi@samsung.com  user_28        mx-28
# 28    seonghwan.kim@samsung.com  user_29        mx-29
#
#                                                실습_URL
# 0   https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 1   https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 2   https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 3   https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 4   https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 5   https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 6   https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 7   https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 8   https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 9   https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 10  https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 11  https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 12  https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 13  https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 14  https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 15  https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 16  https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 17  https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 18  https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 19  https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 20  https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 21  https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 22  https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 23  https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 24  https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 25  https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 26  https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 27  https://d-b8m78vamvqp0.studio.us-east-1.sagema...
# 28  https://d-b8m78vamvqp0.studio.us-east-1.sagema...
